# %% [markdown]
# # Rock Paper Scissor with Tensorflow

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/rps.zip \
    -O /content//rps.zip
  
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/rps-test-set.zip \
    -O /content/rps-test-set.zip
# Out:
# --2021-08-31 03:44:01--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/rps.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.203.128, 74.125.204.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 200682221 (191M) [application/zip]
# Saving to: ‘/content//rps.zip’
#
# /content//rps.zip   100%[===================>] 191.38M  47.6MB/s    in 4.0s
#
# 2021-08-31 03:44:06 (47.6 MB/s) - ‘/content//rps.zip’ saved [200682221/200682221]
#
# --2021-08-31 03:44:06--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/rps-test-set.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.204.128, 64.233.188.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.204.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# Task 1: Specify the directory for Rock, Paper and Scissor respectively


# Task 2: show the directory, including number of images and first 10 images file name
# Out:
# total training rock images: 840
# total training paper images: 840
# total training scissors images: 840
# ['rock05ck01-084.png', 'rock07-k03-018.png', 'rock07-k03-038.png', 'rock05ck01-064.png', 'rock01-055.png', 'rock04-118.png', 'rock04-011.png', 'rock05ck01-053.png', 'rock04-098.png', 'rock02-052.png']
# ['paper04-087.png', 'paper01-015.png', 'paper03-095.png', 'paper04-020.png', 'paper02-100.png', 'paper03-061.png', 'paper04-080.png', 'paper07-038.png', 'paper06-078.png', 'paper04-078.png']
# ['scissors01-089.png', 'scissors02-064.png', 'testscissors02-011.png', 'testscissors03-078.png', 'scissors04-032.png', 'scissors03-073.png', 'testscissors02-055.png', 'scissors03-023.png', 'testscissors01-047.png', 'scissors01-107.png']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Task 3: Show first 10 images with matplotlib (for rock, paper and scissor)

# %% [markdown]
# ## Model Building

# %%
# Task 5: Create a data source and use ImageDataGenerator for data feeding

# %%
# Task 6: Create Layers for Neural Network
# Hint: Try for 1 convolution layer first


# Task 7: Compile Model with optimizers, loss and metrics

# %% [markdown]
# ## Model Training

# %%
# Task 8: Train model and validation with the validation source

# %% [markdown]
# # Using Pretrained Model

# %%
# Additional Task: Use a pre-trained model
